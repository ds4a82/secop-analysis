# %% [markdown]
# # Importe de Archivos SECOP I

# %%
# !pip install pandas
# !pip install sodapy

import pandas as pd
from sodapy import Socrata

client = Socrata("www.datos.gov.co", None)

results = client.get("xvdy-vvsk", limit=2000)

df_secopi = pd.DataFrame.from_records(results)

# %%
df_secopi.head()

# %%
df_secopi.info()

# %% [markdown]
# # Importe de Archivos SECOP II

# %%
import pandas as pd
from sodapy import Socrata


client = Socrata("www.datos.gov.co", None)


results = client.get("p6dx-8zbt", limit=2000)

df_secopii = pd.DataFrame.from_records(results)

# %%
df_secopii

# %%
df_secopii.info()
